-- %% [markdown]
-- # [dbo].[Commit_Issue]

-- %%
USE [SoftwareEngineeringManagement]
GO

-- %%
/****** Object:  Table [dbo].[Commit_Issue]    Script Date: 3/12/2026 4:38:44 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Commit_Issue](
	[commit_id] [int] NOT NULL,
	[jira_issue_id] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[commit_id] ASC,
	[jira_issue_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Commit_Record]

-- %%
/****** Object:  Table [dbo].[Commit_Record]    Script Date: 3/12/2026 4:38:44 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Commit_Record](
	[commit_id] [int] IDENTITY(1,1) NOT NULL,
	[repo_id] [int] NOT NULL,
	[author_id] [int] NOT NULL,
	[commit_hash] [nvarchar](100) NOT NULL,
	[commit_message] [nvarchar](500) NULL,
	[committed_at] [datetime2](7) NOT NULL,
	[lines_added] [int] NOT NULL,
	[lines_deleted] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[commit_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[commit_hash] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Contribution_Report]

-- %%
/****** Object:  Table [dbo].[Contribution_Report]    Script Date: 3/12/2026 4:38:44 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Contribution_Report](
	[report_id] [int] IDENTITY(1,1) NOT NULL,
	[group_id] [int] NOT NULL,
	[user_id] [int] NOT NULL,
	[total_commits] [int] NOT NULL,
	[total_issues_resolved] [int] NOT NULL,
	[total_lines_added] [int] NOT NULL,
	[total_lines_deleted] [int] NOT NULL,
	[calculated_at] [datetime2](7) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[report_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Git_Repository]

-- %%
/****** Object:  Table [dbo].[Git_Repository]    Script Date: 3/12/2026 4:38:44 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Git_Repository](
	[repo_id] [int] IDENTITY(1,1) NOT NULL,
	[group_id] [int] NOT NULL,
	[repo_name] [nvarchar](150) NOT NULL,
	[repo_url] [nvarchar](300) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[repo_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[group_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Group_Leader]

-- %%
/****** Object:  Table [dbo].[Group_Leader]    Script Date: 3/12/2026 4:38:44 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Group_Leader](
	[group_id] [int] NOT NULL,
	[user_id] [int] NOT NULL,
	[assigned_at] [datetime2](7) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[group_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Group_Member]

-- %%
/****** Object:  Table [dbo].[Group_Member]    Script Date: 3/12/2026 4:38:44 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Group_Member](
	[group_id] [int] NOT NULL,
	[user_id] [int] NOT NULL,
	[joined_at] [datetime2](7) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[group_id] ASC,
	[user_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Jira_Issue]

-- %%
/****** Object:  Table [dbo].[Jira_Issue]    Script Date: 3/12/2026 4:38:44 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Jira_Issue](
	[jira_issue_id] [int] IDENTITY(1,1) NOT NULL,
	[jira_project_id] [int] NOT NULL,
	[issue_key] [nvarchar](50) NOT NULL,
	[issue_type] [nvarchar](50) NOT NULL,
	[summary] [nvarchar](300) NOT NULL,
	[status] [nvarchar](50) NOT NULL,
	[priority] [nvarchar](50) NULL,
	[created_at] [datetime2](7) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[jira_issue_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Jira_Project]

-- %%
/****** Object:  Table [dbo].[Jira_Project]    Script Date: 3/12/2026 4:38:44 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Jira_Project](
	[jira_project_id] [int] IDENTITY(1,1) NOT NULL,
	[group_id] [int] NOT NULL,
	[project_key] [nvarchar](50) NOT NULL,
	[project_name] [nvarchar](150) NOT NULL,
	[base_url] [nvarchar](300) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[jira_project_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[group_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Lecturer_Assignment]

-- %%
/****** Object:  Table [dbo].[Lecturer_Assignment]    Script Date: 3/12/2026 4:38:44 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Lecturer_Assignment](
	[lecturer_id] [int] NOT NULL,
	[group_id] [int] NOT NULL,
	[assigned_at] [datetime2](7) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[lecturer_id] ASC,
	[group_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Role]

-- %%
/****** Object:  Table [dbo].[Role]    Script Date: 3/12/2026 4:38:44 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Role](
	[role_id] [int] IDENTITY(1,1) NOT NULL,
	[role_name] [nvarchar](50) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[role_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[role_name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Student_Group]

-- %%
/****** Object:  Table [dbo].[Student_Group]    Script Date: 3/12/2026 4:38:44 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Student_Group](
	[group_id] [int] IDENTITY(1,1) NOT NULL,
	[group_name] [nvarchar](100) NOT NULL,
	[semester] [nvarchar](50) NOT NULL,
	[project_title] [nvarchar](200) NOT NULL,
	[created_at] [datetime2](7) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[group_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[User]

-- %%
/****** Object:  Table [dbo].[User]    Script Date: 3/12/2026 4:38:44 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[User](
	[user_id] [int] IDENTITY(1,1) NOT NULL,
	[full_name] [nvarchar](150) NOT NULL,
	[email] [nvarchar](150) NOT NULL,
	[github_username] [nvarchar](100) NULL,
	[is_active] [bit] NOT NULL,
	[created_at] [datetime2](7) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[user_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[email] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[User_Role]

-- %%
/****** Object:  Table [dbo].[User_Role]    Script Date: 3/12/2026 4:38:44 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[User_Role](
	[user_id] [int] NOT NULL,
	[role_id] [int] NOT NULL,
	[assigned_at] [datetime2](7) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[user_id] ASC,
	[role_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__Commit_Re__lines__4D94879B]

-- %%
ALTER TABLE [dbo].[Commit_Record] ADD  DEFAULT ((0)) FOR [lines_added]
GO

-- %% [markdown]
-- # [DF__Commit_Re__lines__4E88ABD4]

-- %%
ALTER TABLE [dbo].[Commit_Record] ADD  DEFAULT ((0)) FOR [lines_deleted]
GO

-- %% [markdown]
-- # [DF__Contribut__total__571DF1D5]

-- %%
ALTER TABLE [dbo].[Contribution_Report] ADD  DEFAULT ((0)) FOR [total_commits]
GO

-- %% [markdown]
-- # [DF__Contribut__total__5812160E]

-- %%
ALTER TABLE [dbo].[Contribution_Report] ADD  DEFAULT ((0)) FOR [total_issues_resolved]
GO

-- %% [markdown]
-- # [DF__Contribut__total__59063A47]

-- %%
ALTER TABLE [dbo].[Contribution_Report] ADD  DEFAULT ((0)) FOR [total_lines_added]
GO

-- %% [markdown]
-- # [DF__Contribut__total__59FA5E80]

-- %%
ALTER TABLE [dbo].[Contribution_Report] ADD  DEFAULT ((0)) FOR [total_lines_deleted]
GO

-- %% [markdown]
-- # [DF__Contribut__calcu__5AEE82B9]

-- %%
ALTER TABLE [dbo].[Contribution_Report] ADD  DEFAULT (sysdatetime()) FOR [calculated_at]
GO

-- %% [markdown]
-- # [DF__Group_Lea__assig__38996AB5]

-- %%
ALTER TABLE [dbo].[Group_Leader] ADD  DEFAULT (sysdatetime()) FOR [assigned_at]
GO

-- %% [markdown]
-- # [DF__Group_Mem__joine__33D4B598]

-- %%
ALTER TABLE [dbo].[Group_Member] ADD  DEFAULT (sysdatetime()) FOR [joined_at]
GO

-- %% [markdown]
-- # [DF__Lecturer___assig__3D5E1FD2]

-- %%
ALTER TABLE [dbo].[Lecturer_Assignment] ADD  DEFAULT (sysdatetime()) FOR [assigned_at]
GO

-- %% [markdown]
-- # [DF__Student_G__creat__30F848ED]

-- %%
ALTER TABLE [dbo].[Student_Group] ADD  DEFAULT (sysdatetime()) FOR [created_at]
GO

-- %% [markdown]
-- # [DF__User__is_active__286302EC]

-- %%
ALTER TABLE [dbo].[User] ADD  DEFAULT ((1)) FOR [is_active]
GO

-- %% [markdown]
-- # [DF__User__created_at__29572725]

-- %%
ALTER TABLE [dbo].[User] ADD  DEFAULT (sysdatetime()) FOR [created_at]
GO

-- %% [markdown]
-- # [DF__User_Role__assig__2C3393D0]

-- %%
ALTER TABLE [dbo].[User_Role] ADD  DEFAULT (sysdatetime()) FOR [assigned_at]
GO

-- %% [markdown]
-- # [FK__Commit_Is__commi__534D60F1]

-- %%
ALTER TABLE [dbo].[Commit_Issue]  WITH CHECK ADD FOREIGN KEY([commit_id])
REFERENCES [dbo].[Commit_Record] ([commit_id])
GO

-- %% [markdown]
-- # [FK__Commit_Is__jira___5441852A]

-- %%
ALTER TABLE [dbo].[Commit_Issue]  WITH CHECK ADD FOREIGN KEY([jira_issue_id])
REFERENCES [dbo].[Jira_Issue] ([jira_issue_id])
GO

-- %% [markdown]
-- # [FK__Commit_Re__autho__5070F446]

-- %%
ALTER TABLE [dbo].[Commit_Record]  WITH CHECK ADD FOREIGN KEY([author_id])
REFERENCES [dbo].[User] ([user_id])
GO

-- %% [markdown]
-- # [FK__Commit_Re__repo___4F7CD00D]

-- %%
ALTER TABLE [dbo].[Commit_Record]  WITH CHECK ADD FOREIGN KEY([repo_id])
REFERENCES [dbo].[Git_Repository] ([repo_id])
GO

-- %% [markdown]
-- # [FK__Contribut__group__5BE2A6F2]

-- %%
ALTER TABLE [dbo].[Contribution_Report]  WITH CHECK ADD FOREIGN KEY([group_id])
REFERENCES [dbo].[Student_Group] ([group_id])
GO

-- %% [markdown]
-- # [FK__Contribut__user___5CD6CB2B]

-- %%
ALTER TABLE [dbo].[Contribution_Report]  WITH CHECK ADD FOREIGN KEY([user_id])
REFERENCES [dbo].[User] ([user_id])
GO

-- %% [markdown]
-- # [FK__Git_Repos__group__49C3F6B7]

-- %%
ALTER TABLE [dbo].[Git_Repository]  WITH CHECK ADD FOREIGN KEY([group_id])
REFERENCES [dbo].[Student_Group] ([group_id])
GO

-- %% [markdown]
-- # [FK__Group_Lea__group__398D8EEE]

-- %%
ALTER TABLE [dbo].[Group_Leader]  WITH CHECK ADD FOREIGN KEY([group_id])
REFERENCES [dbo].[Student_Group] ([group_id])
GO

-- %% [markdown]
-- # [FK__Group_Lea__user___3A81B327]

-- %%
ALTER TABLE [dbo].[Group_Leader]  WITH CHECK ADD FOREIGN KEY([user_id])
REFERENCES [dbo].[User] ([user_id])
GO

-- %% [markdown]
-- # [FK__Group_Mem__group__34C8D9D1]

-- %%
ALTER TABLE [dbo].[Group_Member]  WITH CHECK ADD FOREIGN KEY([group_id])
REFERENCES [dbo].[Student_Group] ([group_id])
GO

-- %% [markdown]
-- # [FK__Group_Mem__user___35BCFE0A]

-- %%
ALTER TABLE [dbo].[Group_Member]  WITH CHECK ADD FOREIGN KEY([user_id])
REFERENCES [dbo].[User] ([user_id])
GO

-- %% [markdown]
-- # [FK__Jira_Issu__jira___45F365D3]

-- %%
ALTER TABLE [dbo].[Jira_Issue]  WITH CHECK ADD FOREIGN KEY([jira_project_id])
REFERENCES [dbo].[Jira_Project] ([jira_project_id])
GO

-- %% [markdown]
-- # [FK__Jira_Proj__group__4316F928]

-- %%
ALTER TABLE [dbo].[Jira_Project]  WITH CHECK ADD FOREIGN KEY([group_id])
REFERENCES [dbo].[Student_Group] ([group_id])
GO

-- %% [markdown]
-- # [FK__Lecturer___group__3F466844]

-- %%
ALTER TABLE [dbo].[Lecturer_Assignment]  WITH CHECK ADD FOREIGN KEY([group_id])
REFERENCES [dbo].[Student_Group] ([group_id])
GO

-- %% [markdown]
-- # [FK__Lecturer___lectu__3E52440B]

-- %%
ALTER TABLE [dbo].[Lecturer_Assignment]  WITH CHECK ADD FOREIGN KEY([lecturer_id])
REFERENCES [dbo].[User] ([user_id])
GO

-- %% [markdown]
-- # [FK__User_Role__role___2E1BDC42]

-- %%
ALTER TABLE [dbo].[User_Role]  WITH CHECK ADD FOREIGN KEY([role_id])
REFERENCES [dbo].[Role] ([role_id])
GO

-- %% [markdown]
-- # [FK__User_Role__user___2D27B809]

-- %%
ALTER TABLE [dbo].[User_Role]  WITH CHECK ADD FOREIGN KEY([user_id])
REFERENCES [dbo].[User] ([user_id])
GO
